# %% [markdown]
# ## Reading Images

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import numpy as np
import os
import cv2
import shutil
from tqdm import tqdm

# %%
def showimg(path, from_array=True, label="", figsize=(3, 3), cmap='gray'):
    """
    Display an image using matplotlib.
    
    Parameters:
    - path: str or numpy array. Path to the image file or the image array to display.
    - from_array: bool. If True, `path` is considered as a numpy array. If False, it's treated as a file path.
    - label: str. Optional title for the image.
    - figsize: tuple. Size of the figure to display.
    - cmap: str. Color map to apply if the image is grayscale.
    
    Returns:
    - None
    """
    if from_array:
        if isinstance(path, np.ndarray):
            plt.figure(figsize=figsize)
            plt.imshow(path, cmap=cmap)
            if label:
                plt.title(label)
            plt.axis('off')
            plt.show()
        else:
            raise ValueError("Expected a numpy array for `path` when `from_array` is True.")
    else:
        if os.path.exists(path):
            image = mpimg.imread(path)
            plt.figure(figsize=figsize)
            plt.imshow(image)
            if label:
                plt.title(label)
            plt.axis('off')
            plt.show()
        else:
            raise FileNotFoundError(f"The file '{path}' does not exist.")

# %% [markdown]
# ## Trying The Process

# %%
showimg('train/BollywoodActorImages/akshay_kumar/36f3127fbe.jpg',from_array=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 showimg('train/BollywoodActorImages/akshay_kumar/36f3127fbe.jpg',from_array=False)
#
# Cell In[2], line 35, in showimg(path, from_array, label, figsize, cmap)
#      33     plt.show()
#      34 else:
# ---> 35     raise FileNotFoundError(f"The file '{path}' does not exist.")
#
# FileNotFoundError: The file 'train/BollywoodActorImages/akshay_kumar/36f3127fbe.jpg' does not exist.

# %%
# Load the pre-trained Haar cascade classifier for face detection
face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
# Load the pre-trained Haar cascade classifier for eye detection
eye_cascade = cv2.CascadeClassifier('./haarcascade_eye_tree_eyeglasses.xml')

# Read the input image and convert it to grayscale
image = cv2.imread('train/akshay_kumar/0d5e3950ba.jpg', cv2.IMREAD_COLOR)  # Load image in color
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale

# Perform face detection
# detectMultiScale returns a list of rectangles where it detects faces
faces = face_cascade.detectMultiScale(image_gray, scaleFactor=1.1, minNeighbors=1, minSize=(30, 30))

# Draw rectangles around the detected faces
image_cpy = image
for (x, y, w, h) in faces:
    # Define the region of interest (ROI) in the grayscale image for each face
    roi = image[y:y+h, x:x+w]
    roi_gray = image_gray[y:y+h, x:x+w]

    # Display the region of interest (face area)
#     showimg(roi)

    # Perform eye detection within the face's ROI
    eyes = eye_cascade.detectMultiScale(roi_gray)

    # Draw rectangles around the detected eyes
    
    if len(eyes)>=2:
        # Show the face area with detected eyes
        print("Eyes Present")
        cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)  # Draw rectangle around each detected face    
        
        showimg(roi)
#         return this roi
    image = image_cpy
# Out:
# Eyes Present

# %% [markdown]
# But Not Croping face Properly also including Bg so we use MTCNN- Multi-Task Cascaded Convolutional Neural Network For Face Detection

# %%
import os
import sys
import contextlib

from mtcnn import MTCNN

# Function to suppress stdout
@contextlib.contextmanager
def suppress_stdout():
    with open(os.devnull, 'w') as fnull:
        with contextlib.redirect_stdout(fnull):
            yield

def detect_faces_mtcnn(image):
    with suppress_stdout():
        detector = MTCNN()
        faces = detector.detect_faces(image)
        rectangles = [face['box'] for face in faces if face['confidence']>0.70]
        images = []
        for rectangle in rectangles:
            x,y,w,h = rectangle
            images.append(image[y:y+h, x:x+w])
        return rectangles,images

image = cv2.imread('./train/akshay_kumar/05aecc2317.jpg')
_,img = detect_faces_mtcnn(image)
showimg(img[0])
# Out:
# WARNING:tensorflow:From C:\Users\Ravi Paliwal\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Ravi Paliwal\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ravi Paliwal\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
def detect_faces_and_eyes(image_path):
    eye_cascade = cv2.CascadeClassifier('./haarcascade_eye_tree_eyeglasses.xml')

    # Read the input image in color
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    if image is None:
        print("Error: Image not found or unable to load.")
        return None

    # Convert the image to grayscale for detection purposes
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Perform face detection
    faces,_ = detect_faces_mtcnn(image)
    # Loop through detected faces
    for (x, y, w, h) in faces:
        # Define the region of interest (ROI) in the color image for each face
        roi_color = image[y:y+h, x:x+w]
        roi_gray = image_gray[y:y+h, x:x+w]  # Grayscale ROI for eye detection

        # Perform eye detection within the face's ROI
        eyes = eye_cascade.detectMultiScale(roi_gray)

        # If exactly two eyes are detected
        if len(eyes) >= 2:
            return roi_color
            
        
    # If no face with exactly two eyes is detected, return None
    return None

x= detect_faces_and_eyes('train/BollywoodActorImages/akshay_kumar/05aecc2317.jpg')

showimg(x) if x is not None else None

# %% [markdown]
# ## Faces Only

# %%
def process_images(source_directory, destination_directory):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_directory):
        os.makedirs(destination_directory)
    
    # Loop through each subdirectory in the source directory
    for subdir in os.listdir(source_directory):
        subdir_path = os.path.join(source_directory, subdir)

        if os.path.isdir(subdir_path):
            count = 1
            # Loop through each file in the subdirectory
            for file in tqdm(os.listdir(subdir_path),desc=f"Processing {subdir}"):
                if file.endswith('.jpg') or file.endswith('.png'):
                    file_path = os.path.join(subdir_path, file)

                    # Process the image to find faces with two eyes
                    face_image = detect_faces_and_eyes(file_path)

                    if face_image is not None:
                        # Save the detected face region
                        destination_path = os.path.join(destination_directory, f"{subdir}_{count}.jpg")
                        cv2.imwrite(destination_path, face_image)
#                         print(f"Saved face with two eyes to {destination_path}")
                        count += 1

    print("Processing and saving faces completed.")

# Example usage:
source_directory = "./train/BollywoodActorImages/"
destination_directory = "./TrainData/FaceImages"
process_images(source_directory, destination_directory)

# %% [markdown]
# ## Resizing Images

# %%
import cv2
source = './TrainData/FaceImages'
resized_dest = 'TrainData/ResizedFaces'

if not os.path.exists(resized_dest):
    os.makedirs(resized_dest)
    
target_size = (224,112)   

for filename in tqdm(os.listdir(source), desc=f"Resizing. to {target_size}"):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        # Read the image
        img = cv2.imread(os.path.join(source, filename))
        
        # Resize the image
        resized_img = cv2.resize(img, target_size)
        
        # Save the resized image to the output directory
        cv2.imwrite(os.path.join(resized_dest, filename), resized_img)

print("Resizing complete.")
# Out:
# Resizing. to (224, 112): 100%|██████████████████████████████████████████████████████| 214/214 [00:00<00:00, 259.06it/s]
# Resizing complete.

# %%
showimg('TrainData/ResizedFaces/ajay_devgn_1.jpg',from_array=False)

# %% [markdown]
# ### Wavelet Transformation

# %%
import numpy as np
import pywt
import cv2    

# From Stackoverflow
def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H


# Example 
input_img = cv2.imread('./TrainData/ResizedFaces/ajay_devgn_1.jpg')
im_wt = w2d(input_img,'db1',5)
showimg(im_wt)

# %%
# def w2d(image):
#     # 1. Apply Gaussian blur for smoothing
#     blurred = cv2.GaussianBlur(image, (5, 5), 0)
#     # 2. Apply thresholding
#     _, thresholded = cv2.threshold(blurred, 100, 255, cv2.THRESH_BINARY)
#     # 3. Apply Canny edge detection
#     edges = cv2.Canny(thresholded, 50, 150)
    
#     return edges

# %% [markdown]
# ### Now I am Trying To Vertically Stack the Original Image And Wavelett transformed Image. and Store all in array.

# %%
combined_images = []
for training_image in tqdm(os.listdir('./TrainData/ResizedFaces/')):
    # Read and resize the original color image
    original_img = cv2.imread(f"./TrainData/ResizedFaces/{training_image}")
    resized_original_img = cv2.resize(original_img, (224, 112))
    
    # Perform wavelet transformation and resize the resulting grayscale image
    wavelet_img = w2d(original_img, 'db1', 8)
    
    resized_wavelet_img = cv2.resize(wavelet_img, (224, 112))
    
    # Convert grayscale wavelet transformed image to color (BGR)
    wavelet_img_color = cv2.cvtColor(resized_wavelet_img, cv2.COLOR_GRAY2BGR)
    
    # Concatenate color and grayscale images vertically
    combined_img = np.concatenate((resized_original_img, wavelet_img_color), axis=0)
    
    combined_images.append(combined_img)

# combined_images now contains the vertically concatenated images
X=combined_images
# Out:
#   0%|                                                                                                                          | 0/214 [00:00<?, ?it/s]C:\ProgramData\anaconda3\Lib\site-packages\pywt\_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 214/214 [00:01<00:00, 129.07it/s]

# %%
showimg(X[0])

# %%
combined_images = []
for training_image in tqdm(os.listdir('./TrainData/ResizedFaces/')):
    # Read and resize the original color image
    original_img = cv2.imread(f"./TrainData/ResizedFaces/{training_image}")
    resized_original_img = cv2.resize(original_img, (224, 224))
    
    # Perform wavelet transformation and resize the resulting grayscale image
    wavelet_img = w2d(original_img, 'db1', 8)
    
    resized_wavelet_img = cv2.resize(wavelet_img, (224, 224))
    
    # Convert grayscale wavelet transformed image to color (BGR)
    wavelet_img_color = cv2.cvtColor(resized_wavelet_img, cv2.COLOR_GRAY2BGR)
    
    # Concatenate color and grayscale images vertically
#     combined_img = np.concatenate((resized_original_img, wavelet_img_color), axis=0)
    combined_img = resized_original_img
    
    combined_images.append(combined_img)

# combined_images now contains the vertically concatenated images
X=combined_images
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 214/214 [00:01<00:00, 153.80it/s]

# %%
showimg(X[0])

# %%
ProcessedImages= np.array(X)
np.save('CombinedProcessedImages.npy',ProcessedImages)

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input

# Load the VGG16 model with pre-trained weights on ImageNet
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Function to extract embeddings (features) from an image
def extract_embeddings(x):
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    features = base_model.predict(x,verbose=False)
    return features.flatten()

embedding = extract_embeddings(X[0])
print(f"Embedding shape: {embedding.shape}, Embeddings {embedding}")
# Out:
# Embedding shape: (25088,), Embeddings [0.       0.       0.       ... 9.553433 0.       0.      ]

# %%
Features = []
for image in tqdm(X,desc='Extracting Features'):
    Features.append(extract_embeddings(image))
# Out:
# Extracting Features: 100%|███████████████████████████████████████████████████████████| 214/214 [01:22<00:00,  2.60it/s]

# %%
NpFeatures = np.array(Features)
np.save('Vgg16Features.npy',NpFeatures)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler,MinMaxScaler
# scaler = StandardScaler()
# scaled_features = scaler.fit_transform(NpFeatures)

# Number of clusters
num_clusters = 10

# Apply K-means clustering on extracted features
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(NpFeatures)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
mapping = {}
for i,file in enumerate(os.listdir('./TrainData/ResizedFaces/')):
    mapping[f"./TrainData/ResizedFaces/{file}"] = cluster_labels[i]

# %%
mapping
# Out:
# {'./TrainData/ResizedFaces/ajay_devgn_1.jpg': 2,
#  './TrainData/ResizedFaces/ajay_devgn_2.jpg': 8,
#  './TrainData/ResizedFaces/ajay_devgn_3.jpg': 0,
#  './TrainData/ResizedFaces/ajay_devgn_4.jpg': 2,
#  './TrainData/ResizedFaces/ajay_devgn_5.jpg': 7,
#  './TrainData/ResizedFaces/ajay_devgn_6.jpg': 2,
#  './TrainData/ResizedFaces/ajay_devgn_7.jpg': 0,
#  './TrainData/ResizedFaces/akshay_kumar_1.jpg': 2,
#  './TrainData/ResizedFaces/akshay_kumar_10.jpg': 8,
#  './TrainData/ResizedFaces/akshay_kumar_11.jpg': 8,
#  './TrainData/ResizedFaces/akshay_kumar_12.jpg': 2,
#  './TrainData/ResizedFaces/akshay_kumar_13.jpg': 2,
#  './TrainData/ResizedFaces/akshay_kumar_2.jpg': 2,
#  './TrainData/ResizedFaces/akshay_kumar_3.jpg': 2,
#  './TrainData/ResizedFaces/akshay_kumar_4.jpg': 2,
#  './TrainData/ResizedFaces/akshay_kumar_5.jpg': 2,
#  './TrainData/ResizedFaces/akshay_kumar_6.jpg': 2,
#  './TrainData/ResizedFaces/akshay_kumar_7.jpg': 8,
#  './TrainData/ResizedFaces/akshay_kumar_8.jpg': 0,
#  './TrainData/ResizedFaces/akshay_kumar_9.jpg': 0,
#  './TrainData/ResizedFaces/anupam_kher_1.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_10.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_11.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_12.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_13.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_14.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_15.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_16.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_17.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_18.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_19.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_2.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_20.jpg': 1,
#  './TrainData/ResizedFaces/anupam_kher_21.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_22.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_23.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_24.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_25.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_3.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_4.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_5.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_6.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_7.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_8.jpg': 2,
#  './TrainData/ResizedFaces/anupam_kher_9.jpg': 2,
#  './TrainData/ResizedFaces/deepika_padukone_1.jpg': 4,
#  './TrainData/ResizedFaces/deepika_padukone_10.jpg': 9,
#  './TrainData/ResizedFaces/deepika_padukone_11.jpg': 4,
#  './TrainData/ResizedFaces/deepika_padukone_12.jpg': 2,
#  './TrainData/ResizedFaces/deepika_padukone_13.jpg': 8,
#  './TrainData/ResizedFaces/deepika_padukone_14.jpg': 8,
#  './TrainData/ResizedFaces/deepika_padukone_15.jpg': 8,
#  './TrainData/ResizedFaces/deepika_padukone_16.jpg': 4,
#  './TrainData/ResizedFaces/deepika_padukone_17.jpg': 8,
#  './TrainData/ResizedFaces/deepika_padukone_18.jpg': 1,
#  './TrainData/ResizedFaces/deepika_padukone_19.jpg': 5,
#  './TrainData/ResizedFaces/deepika_padukone_2.jpg': 8,
#  './TrainData/ResizedFaces/deepika_padukone_20.jpg': 8,
#  './TrainData/ResizedFaces/deepika_padukone_21.jpg': 1,
#  './TrainData/ResizedFaces/deepika_padukone_3.jpg': 8,
#  './TrainData/ResizedFaces/deepika_padukone_4.jpg': 2,
#  './TrainData/ResizedFaces/deepika_padukone_5.jpg': 4,
#  './TrainData/ResizedFaces/deepika_padukone_6.jpg': 1,
#  './TrainData/ResizedFaces/deepika_padukone_7.jpg': 1,
#  './TrainData/ResizedFaces/deepika_padukone_8.jpg': 3,
#  './TrainData/ResizedFaces/deepika_padukone_9.jpg': 1,
#  './TrainData/ResizedFaces/farida_jalal_1.jpg': 8,
#  './TrainData/ResizedFaces/farida_jalal_10.jpg': 8,
#  './TrainData/ResizedFaces/farida_jalal_11.jpg': 2,
#  './TrainData/ResizedFaces/farida_jalal_12.jpg': 5,
#  './TrainData/ResizedFaces/farida_jalal_13.jpg': 5,
#  './TrainData/ResizedFaces/farida_jalal_14.jpg': 8,
#  './TrainData/ResizedFaces/farida_jalal_15.jpg': 6,
#  './TrainData/ResizedFaces/farida_jalal_16.jpg': 6,
#  './TrainData/ResizedFaces/farida_jalal_17.jpg': 2,
#  './TrainData/ResizedFaces/farida_jalal
jpg': 1,
#  './TrainData/ResizedFaces/madhuri_dixit_22.jpg': 5,
#  './TrainData/ResizedFaces/madhuri_dixit_23.jpg': 5,
#  './TrainData/ResizedFaces/madhuri_dixit_24.jpg': 5,
#  './TrainData/ResizedFaces/madhuri_dixit_25.jpg': 5,
#  './TrainData/ResizedFaces/madhuri_dixit_3.jpg': 5,
#  './TrainData/ResizedFaces/madhuri_dixit_4.jpg': 1,
#  './TrainData/ResizedFaces/madhuri_dixit_5.jpg': 4,
#  './TrainData/ResizedFaces/madhuri_dixit_6.jpg': 1,
#  './TrainData/ResizedFaces/madhuri_dixit_7.jpg': 1,
#  './TrainData/ResizedFaces/madhuri_dixit_8.jpg': 1,
#  './TrainData/ResizedFaces/madhuri_dixit_9.jpg': 8,
#  './TrainData/ResizedFaces/saif_ali_khan_1.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_10.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_11.jpg': 8,
#  './TrainData/ResizedFaces/saif_ali_khan_12.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_13.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_14.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_15.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_16.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_17.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_18.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_19.jpg': 2,
#  './TrainData/ResizedFaces/saif_ali_khan_2.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_20.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_21.jpg': 1,
#  './TrainData/ResizedFaces/saif_ali_khan_22.jpg': 2,
#  './TrainData/ResizedFaces/saif_ali_khan_23.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_3.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_4.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_5.jpg': 4,
#  './TrainData/ResizedFaces/saif_ali_khan_6.jpg': 2,
#  './TrainData/ResizedFaces/saif_ali_khan_7.jpg': 0,
#  './TrainData/ResizedFaces/saif_ali_khan_8.jpg': 2,
#  './TrainData/ResizedFaces/saif_ali_khan_9.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_1.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_10.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_11.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_12.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_13.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_2.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_3.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_4.jpg': 8,
#  './TrainData/ResizedFaces/shah_rukh_khan_5.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_6.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_7.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_8.jpg': 2,
#  './TrainData/ResizedFaces/shah_rukh_khan_9.jpg': 0,
#  './TrainData/ResizedFaces/vidya_balan_1.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_10.jpg': 1,
#  './TrainData/ResizedFaces/vidya_balan_11.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_12.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_13.jpg': 1,
#  './TrainData/ResizedFaces/vidya_balan_14.jpg': 8,
#  './TrainData/ResizedFaces/vidya_balan_15.jpg': 1,
#  './TrainData/ResizedFaces/vidya_balan_16.jpg': 1,
#  './TrainData/ResizedFaces/vidya_balan_17.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_18.jpg': 8,
#  './TrainData/ResizedFaces/vidya_balan_19.jpg': 1,
#  './TrainData/ResizedFaces/vidya_balan_2.jpg': 1,
#  './TrainData/ResizedFaces/vidya_balan_20.jpg': 1,
#  './TrainData/ResizedFaces/vidya_balan_21.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_22.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_23.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_24.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_25.jpg': 8,
#  './TrainData/ResizedFaces/vidya_balan_26.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_27.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_28.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_3.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_4.jpg': 1,
#  './TrainData/ResizedFaces/vidya_balan_5.jpg': 8,
#  './TrainData/ResizedFaces/vidya_balan_6.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_7.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_8.jpg': 4,
#  './TrainData/ResizedFaces/vidya_balan_9.jpg': 8}

# %%
for image_path, cluster_label in mapping.items():
    cluster_folder = f'ClustersKmeans/Cluster_{cluster_label}/'
    os.makedirs(cluster_folder, exist_ok=True)
    
    filename = os.path.basename(image_path)
    destination_path = os.path.join(cluster_folder, filename)
    
    try:
        shutil.copyfile(image_path, destination_path)
        print(f"Copied '{filename}' to '{cluster_folder}'")
    except FileNotFoundError:
        print(f"Error: '{filename}' not found in '{images_folder}'")
    except FileExistsError:
        print(f"Error: '{filename}' already exists in '{cluster_folder}'")
# Out:
# Copied 'ajay_devgn_1.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'ajay_devgn_2.jpg' to 'ClustersKmeans/Cluster_8/'
# Copied 'ajay_devgn_3.jpg' to 'ClustersKmeans/Cluster_0/'
# Copied 'ajay_devgn_4.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'ajay_devgn_5.jpg' to 'ClustersKmeans/Cluster_7/'
# Copied 'ajay_devgn_6.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'ajay_devgn_7.jpg' to 'ClustersKmeans/Cluster_0/'
# Copied 'akshay_kumar_1.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'akshay_kumar_10.jpg' to 'ClustersKmeans/Cluster_8/'
# Copied 'akshay_kumar_11.jpg' to 'ClustersKmeans/Cluster_8/'
# Copied 'akshay_kumar_12.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'akshay_kumar_13.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'akshay_kumar_2.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'akshay_kumar_3.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'akshay_kumar_4.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'akshay_kumar_5.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'akshay_kumar_6.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'akshay_kumar_7.jpg' to 'ClustersKmeans/Cluster_8/'
# Copied 'akshay_kumar_8.jpg' to 'ClustersKmeans/Cluster_0/'
# Copied 'akshay_kumar_9.jpg' to 'ClustersKmeans/Cluster_0/'
# Copied 'anupam_kher_1.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_10.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_11.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_12.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_13.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_14.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_15.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_16.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_17.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_18.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_19.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_2.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_20.jpg' to 'ClustersKmeans/Cluster_1/'
# Copied 'anupam_kher_21.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_22.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_23.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_24.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_25.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_3.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher_4.jpg' to 'ClustersKmeans/Cluster_2/'
# Copied 'anupam_kher
jpg' to 'ClustersKmeans/Cluster_4/'
# Copied 'vidya_balan_4.jpg' to 'ClustersKmeans/Cluster_1/'
# Copied 'vidya_balan_5.jpg' to 'ClustersKmeans/Cluster_8/'
# Copied 'vidya_balan_6.jpg' to 'ClustersKmeans/Cluster_4/'
# Copied 'vidya_balan_7.jpg' to 'ClustersKmeans/Cluster_4/'
# Copied 'vidya_balan_8.jpg' to 'ClustersKmeans/Cluster_4/'
# Copied 'vidya_balan_9.jpg' to 'ClustersKmeans/Cluster_8/'

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def select_n_components_variance(images, variance_threshold=0.95):
    pca = PCA()
    pca.fit(NpFeatures)
    
    # Plot explained variance ratio
    explained_variance_ratio = pca.explained_variance_ratio_
    cumulative_variance_ratio = np.cumsum(explained_variance_ratio)
    
    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(cumulative_variance_ratio, marker='o', linestyle='--', color='b')
    plt.xlabel('Number of Components')
    plt.ylabel('Cumulative Explained Variance Ratio')
    plt.title('Explained Variance Ratio vs Number of Components')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    # Determine the number of components that explain variance_threshold of the variance
    n_components = np.argmax(cumulative_variance_ratio >= variance_threshold) + 1
    print(f'Number of components for {variance_threshold} variance threshold: {n_components}')
    
    return n_components

# Example usage
# Assuming `images` is your dataset of flattened images
# images should be a 2D array with shape (num_samples, num_features)
# where num_samples is the number of images and num_features is the flattened image size

# Selecting number of components that explain at least 95% variance
n_components = select_n_components_variance(Features, variance_threshold=0.95)
# Out:
# Number of components for 0.95 variance threshold: 171

# %%
def perform_pca(images, n_components=171):
    pca = PCA(n_components=n_components)
    pca.fit(images)
    transformed_images = pca.transform(images)
    return transformed_images

# %%
A = perform_pca(NpFeatures)
cluster_labels = kmeans.fit_predict(A)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
A[0]
# Out:
# array([ 258.2748    ,   18.80244   , -232.95702   ,   38.069317  ,
#          13.966565  , -268.84973   ,  -38.82118   ,  -50.064167  ,
#         -71.409744  , -110.3049    ,  -93.190384  , -142.79759   ,
#          36.384655  ,   64.802826  ,   74.981636  ,  104.47545   ,
#          56.961895  ,  -25.347448  , -109.864075  ,  111.961876  ,
#         180.05089   ,  -97.920975  ,  100.11006   ,   78.05385   ,
#         -44.15799   ,   67.24379   ,  162.32747   ,  -48.85646   ,
#           0.39145327,  138.80588   ,   43.456654  ,    1.316392  ,
#          18.330784  , -113.7122    ,  -86.68002   ,   15.065592  ,
#         -71.55868   ,  -32.186714  ,  -10.195932  ,   60.08016   ,
#        -176.92227   ,  145.09987   ,   75.14984   ,  -54.097637  ,
#          72.00421   ,   20.40098   ,   76.22438   ,   12.913254  ,
#          91.87185   ,   61.91492   ,   70.38263   ,  -76.03623   ,
#         -18.50113   ,   32.48065   ,   -4.0103745 ,   29.568037  ,
#          28.15364   ,  184.87671   ,   95.53658   ,   98.402756  ,
#          36.087906  ,   42.940998  ,   36.272194  ,   32.99462   ,
#          37.972374  ,  -14.390104  ,   67.767006  ,  -38.249645  ,
#          59.628567  ,   87.07494   ,  116.32028   ,   58.372383  ,
#         -77.60049   ,   31.20072   ,  -49.612926  , -114.402306  ,
#         119.007286  ,  -79.92785   ,  -97.48284   ,    6.5289736 ,
#        -133.5204    ,  -13.452511  , -102.74104   ,   52.93326   ,
#          -4.0429173 ,  142.76028   ,  111.21526   ,  -25.704454  ,
#         -42.504387  ,  137.8025    ,  -66.62104   ,    8.60393   ,
#         -78.77105   ,   25.042475  ,   66.66261   ,  -41.19977   ,
#         -38.477142  ,  -15.61997   , -135.13585   ,   19.822903  ,
#          17.597927  ,  -54.22839   ,   35.487854  ,   68.74344   ,
#        -111.51536   ,   11.058516  ,  -28.594595  ,   65.46623   ,
#          74.83267   ,   76.57562   ,   63.68866   ,  -90.260994  ,
#          63.091564  ,   -6.322962  ,   90.94034   ,  -53.92795   ,
#          24.881392  ,    3.303461  ,   12.705481  , -110.033455  ,
#         151.84319   ,   46.83464   ,  -54.032463  ,  -19.352707  ,
#          88.77675   ,  -54.934258  ,  -51.589184  ,   26.25856   ,
#         -32.62415   ,  -22.802807  ,  -30.89959   ,   34.211838  ,
#          38.282475  ,  -10.166521  ,  -65.01274   ,   62.873672  ,
#         -21.241325  ,  -41.078346  ,   11.85747   ,    0.6549511 ,
#          48.212852  ,   22.36822   ,  -15.589235  ,  -14.734867  ,
#          -4.346827  ,  -33.527172  ,   23.79305   ,  -10.776144  ,
#          33.590252  ,  -57.17126   ,   64.601616  ,   16.91232   ,
#         -24.559015  ,  -18.020689  ,  -21.940384  ,   20.43246   ,
#          32.105576  ,   65.37506   ,  -23.621231  ,    9.9748125 ,
#          16.286907  ,  -18.901674  ,  -49.734634  ,  -36.045208  ,
#          -5.8239746 ,   19.667236  ,    6.257038  ,   12.456326  ,
#          26.983952  ,   -6.051754  ,  -12.876627  ], dtype=float32)

# %%
mapping = {}
for i,file in enumerate(os.listdir('./TrainData/ResizedFaces/')):
    mapping[f"./TrainData/ResizedFaces/{file}"] = cluster_labels[i]

# %%
for image_path, cluster_label in mapping.items():
    cluster_folder = f'ClustersPCAKmeans/Cluster_{cluster_label}/'
    os.makedirs(cluster_folder, exist_ok=True)
    
    filename = os.path.basename(image_path)
    destination_path = os.path.join(cluster_folder, filename)
    
    try:
        shutil.copyfile(image_path, destination_path)
        print(f"Copied '{filename}' to '{cluster_folder}'")
    except FileNotFoundError:
        print(f"Error: '{filename}' not found in '{images_folder}'")
    except FileExistsError:
        print(f"Error: '{filename}' already exists in '{cluster_folder}'")
# Out:
# Copied 'ajay_devgn_1.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'ajay_devgn_2.jpg' to 'ClustersPCAKmeans/Cluster_5/'
# Copied 'ajay_devgn_3.jpg' to 'ClustersPCAKmeans/Cluster_3/'
# Copied 'ajay_devgn_4.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'ajay_devgn_5.jpg' to 'ClustersPCAKmeans/Cluster_3/'
# Copied 'ajay_devgn_6.jpg' to 'ClustersPCAKmeans/Cluster_6/'
# Copied 'ajay_devgn_7.jpg' to 'ClustersPCAKmeans/Cluster_0/'
# Copied 'akshay_kumar_1.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'akshay_kumar_10.jpg' to 'ClustersPCAKmeans/Cluster_2/'
# Copied 'akshay_kumar_11.jpg' to 'ClustersPCAKmeans/Cluster_2/'
# Copied 'akshay_kumar_12.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'akshay_kumar_13.jpg' to 'ClustersPCAKmeans/Cluster_0/'
# Copied 'akshay_kumar_2.jpg' to 'ClustersPCAKmeans/Cluster_3/'
# Copied 'akshay_kumar_3.jpg' to 'ClustersPCAKmeans/Cluster_6/'
# Copied 'akshay_kumar_4.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'akshay_kumar_5.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'akshay_kumar_6.jpg' to 'ClustersPCAKmeans/Cluster_5/'
# Copied 'akshay_kumar_7.jpg' to 'ClustersPCAKmeans/Cluster_5/'
# Copied 'akshay_kumar_8.jpg' to 'ClustersPCAKmeans/Cluster_3/'
# Copied 'akshay_kumar_9.jpg' to 'ClustersPCAKmeans/Cluster_3/'
# Copied 'anupam_kher_1.jpg' to 'ClustersPCAKmeans/Cluster_5/'
# Copied 'anupam_kher_10.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'anupam_kher_11.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_12.jpg' to 'ClustersPCAKmeans/Cluster_5/'
# Copied 'anupam_kher_13.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_14.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_15.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_16.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_17.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_18.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_19.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_2.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_20.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'anupam_kher_21.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_22.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_23.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_24.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_25.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_3.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_4.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_5.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_6.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_7.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_8.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'anupam_kher_9.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'deepika_padukone_1.jpg' to 'ClustersPCAKmeans/Cluster_9/'
# Copied 'deepika_padukone_10.jpg' to 'ClustersPCAKmeans/Cluster_9/'
# Copied 'deepika_padukone_11.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'deepika_padukone_12.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'deepika_padukone_13.jpg' to 'ClustersPCAKmeans/Cluster_2/'
# Copied 'deepika_padukone_14.jpg' to 'ClustersPCAKmeans/Cluster_2/'
# Copied 'deepika_padukone_15.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'deepika_padukone_16.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'deepika_padukone_17.jpg' to 'ClustersPCAKmeans/Cluster_2/'
# Copied 'deepika_padukone_18.jpg' to 'ClustersPCAKmeans/Cluster_9/'
# Copied 'deepika_padukone_19.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'deepika_padukone_2.jpg' to 'ClustersPCAKmeans/Cluster_2/'
# Copied 'deepika_padukone_20.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'deepika_padukone_21.jpg' to 'ClustersPCAKmeans/Cluster_9/'
# Copied 'deepika_padukone_3.jpg' to 'ClustersPCAKmeans/Cluster_1/'
# Copied 'deepika_padukone_4.jpg' to 'ClustersPCAKmeans/Cluster_7/'
# Copied 'deepika_padukone_5.jpg' to 'ClustersPCAKmeans/Cluster_9/'
# Copied 'deepika_padukone_6.jpg' to 'ClustersPCAKmeans/Cluster_4/'
# Copied 
# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler,MinMaxScaler
scaler = StandardScaler()
scaled_features = scaler.fit_transform(A)

# Number of clusters
num_clusters = 10

# Apply K-means clustering on extracted features
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(scaled_features)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Out:
# array([ 1.2418013 ,  0.10846519, -1.4723692 ,  0.25693083,  0.09992865,
#        -2.0183227 , -0.31246427, -0.4094405 , -0.61006767, -0.97035265,
#        -0.87030125, -1.3755386 ,  0.35863778,  0.65129304,  0.7593995 ,
#         1.0830742 ,  0.5927307 , -0.27186298, -1.1880771 ,  1.2242291 ,
#         2.0301657 , -1.1140238 ,  1.1558379 ,  0.91644406, -0.5193171 ,
#         0.8115493 ,  1.9724706 , -0.596311  ,  0.00481215,  1.7232194 ,
#         0.55166394,  0.01684263,  0.23562287, -1.4663167 , -1.1238614 ,
#         0.19696574, -0.9465449 , -0.43046966, -0.1374127 ,  0.8149243 ,
#        -2.405041  ,  1.9897766 ,  1.0347735 , -0.75430715,  1.0079784 ,
#         0.28681538,  1.0918432 ,  0.18594144,  1.3326393 ,  0.899535  ,
#         1.0267802 , -1.115361  , -0.27401018,  0.48596448, -0.06024137,
#         0.44478247,  0.42504805,  2.8297622 ,  1.4707137 ,  1.5188143 ,
#         0.5602616 ,  0.66963595,  0.5678266 ,  0.51855725,  0.5996337 ,
#        -0.23054697,  1.0957757 , -0.619956  ,  0.9710118 ,  1.4280963 ,
#         1.9101657 ,  0.9595386 , -1.2895075 ,  0.51972145, -0.8288418 ,
#        -1.9225837 ,  2.0079863 , -1.3568268 , -1.6653149 ,  0.11169717,
#        -2.293198  , -0.23274763, -1.7820871 ,  0.9220316 , -0.07093516,
#         2.5178962 ,  1.9653658 , -0.45778802, -0.75974303,  2.4658978 ,
#        -1.1978945 ,  0.15573137, -1.4297687 ,  0.45619267,  1.2217684 ,
#        -0.75640553, -0.712046  , -0.28945127, -2.5166683 ,  0.37085062,
#         0.33121836, -1.0237532 ,  0.6705735 ,  1.3025696 , -2.1381633 ,
#         0.21282926, -0.5528588 ,  1.2659295 ,  1.4645914 ,  1.5045677 ,
#         1.2540203 , -1.7865887 ,  1.2519267 , -0.12572415,  1.8182917 ,
#        -1.0824    ,  0.50080943,  0.06689376,  0.25835994, -2.2473178 ,
#         3.1102076 ,  0.9657481 , -1.118209  , -0.40317848,  1.8542898 ,
#        -1.1550833 , -1.0908139 ,  0.5563369 , -0.6941061 , -0.48562288,
#        -0.66113776,  0.73705083,  0.8264515 , -0.22044258, -1.4188714 ,
#         1.3767658 , -0.46767172, -0.9102184 ,  0.26359066,  0.01460914,
#         1.0826883 ,  0.50369817, -0.35253495, -0.3349225 , -0.09935109,
#        -0.7706137 ,  0.54952365, -0.24919818,  0.7792034 , -1.3425897 ,
#         1.5229771 ,  0.40067494, -0.5828934 , -0.43163723, -0.5283213 ,
#         0.4943755 ,  0.7808543 ,  1.5999024 , -0.5822762 ,  0.24636878,
#         0.40395138, -0.4753241 , -1.2571819 , -0.91441464, -0.1481366 ,
#         0.5042014 ,  0.16094129,  0.32285416,  0.70708233, -0.15972064,
#        -0.34022936], dtype=float32)

# %%
mapping = {}
for i,file in enumerate(os.listdir('./TrainData/ResizedFaces/')):
    mapping[f"./TrainData/ResizedFaces/{file}"] = cluster_labels[i]

# %%
for image_path, cluster_label in mapping.items():
    cluster_folder = f'ClustersPCAKmeansScalled/Cluster_{cluster_label}/'
    os.makedirs(cluster_folder, exist_ok=True)
    
    filename = os.path.basename(image_path)
    destination_path = os.path.join(cluster_folder, filename)
    
    try:
        shutil.copyfile(image_path, destination_path)
        print(f"Copied '{filename}' to '{cluster_folder}'")
    except FileNotFoundError:
        print(f"Error: '{filename}' not found in '{images_folder}'")
    except FileExistsError:
        print(f"Error: '{filename}' already exists in '{cluster_folder}'")
# Out:
# Copied 'ajay_devgn_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'ajay_devgn_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'ajay_devgn_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'ajay_devgn_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'ajay_devgn_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'ajay_devgn_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'ajay_devgn_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_8/'
# Copied 'akshay_kumar_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_5/'
# Copied 'akshay_kumar_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'akshay_kumar_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_0/'
# Copied 'anupam_kher_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_0/'
# Copied 'anupam_kher_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_14.jpg' to 'ClustersPCAKmeansScalled/Cluster_1/'
# Copied 'anupam_kher_15.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_16.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_17.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_18.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_19.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_20.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_21.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_22.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_23.jpg' to 'ClustersPCAKmeansScalled/Cluster_1/'
# Copied 'anupam_kher_24.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_25.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'anupam_kher_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'anupam_kher_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'deepika_padukone_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'deepika_padukone_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'deepika_padukone_14.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_15.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_16.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_17.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_18.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_19.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_2/'
# Copied 'deepika_padukone_20.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_21.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'deepika_padukone_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'deepika_padukone_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'deepika_padukone_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'deepika_padukone_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_14.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_15.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_16.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_17.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_18.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_19.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_20.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_21.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_22.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_23.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_24.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_25.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_26.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_27.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_28.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_29.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_30.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_31.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_32.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'farida_jalal_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'farida_jalal_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_14.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_15.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_16.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_17.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_18.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_19.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_20.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_21.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_22.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_23.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_24.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_25.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_26.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_27.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_7/'
# Copied 'kajol_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'kajol_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'kajol_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_14.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_15.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_16.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_17.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'madhuri_dixit_18.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'madhuri_dixit_19.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_20.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'madhuri_dixit_21.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'madhuri_dixit_22.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_23.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_24.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_25.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'madhuri_dixit_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'madhuri_dixit_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'saif_ali_khan_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_14.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'saif_ali_khan_15.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_16.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_17.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_18.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_19.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_20.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_21.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_22.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'saif_ali_khan_23.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_4/'
# Copied 'saif_ali_khan_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_9/'
# Copied 'saif_ali_khan_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'saif_ali_khan_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'saif_ali_khan_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_9/'
# Copied 'saif_ali_khan_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'saif_ali_khan_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'shah_rukh_khan_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'shah_rukh_khan_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'shah_rukh_khan_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'shah_rukh_khan_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'shah_rukh_khan_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'shah_rukh_khan_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'shah_rukh_khan_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'shah_rukh_khan_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'shah_rukh_khan_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'shah_rukh_khan_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'shah_rukh_khan_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'shah_rukh_khan_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'shah_rukh_khan_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_1.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_10.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_11.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_12.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_13.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'vidya_balan_14.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_15.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_16.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_17.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_18.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_19.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_2.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'vidya_balan_20.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_21.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'vidya_balan_22.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_23.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'vidya_balan_24.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'vidya_balan_25.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'vidya_balan_26.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_27.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_28.jpg' to 'ClustersPCAKmeansScalled/Cluster_6/'
# Copied 'vidya_balan_3.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_4.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_5.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_6.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_7.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_8.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
# Copied 'vidya_balan_9.jpg' to 'ClustersPCAKmeansScalled/Cluster_3/'
